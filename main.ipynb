# %% [markdown]
# ### Instalar Bibliotecas

# %%
#!pip install duckdb
#!pip install pandas
#!pip install plotly
#!pip install matplotlib
#!pip install seaborn

# %% [markdown]
# ### Importar Bibliotecas

# %%
import duckdb
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importar Funções

# %%
#import lib.dadosaberto as da
#import lib.functions as f
#import lib.config as cfg

# %% [markdown]
# ### Conecta no DuckDB

# %%
# Conecta abrindo / criando um arquivo
conn = duckdb.connect('./dados/empresa_br.db')

# Conecta na memória
comem = duckdb.connect()

# %% [markdown]
# ### Executar Query

# %%
# Consultar as tabelas do schema main
query = '''
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'main';
    '''
conn.execute(query)

# %%
# Usando fetchone
result_one = conn.execute(query).fetchone()
print(type(result_one))
print("Retorna um registro:", result_one)
print('-'*80)

# Usando fetchall
result_all = conn.execute(query).fetchall()
print(type(result_all))
print("Retorna a lista dos registros:", result_all)
print('-'*80)

# Usando fetchdf
result_df = conn.execute(query).fetchdf()
print(type(result_df))
print("Retorna Data Frame")
result_df
# Out:
# <class 'tuple'>
# Retorna um registro: ('bronze_cnae',)
# --------------------------------------------------------------------------------
# <class 'list'>
# Retorna a lista dos registros: [('bronze_cnae',), ('bronze_empresa_0',), ('bronze_empresa_1',), ('bronze_empresa_2',), ('bronze_empresa_3',), ('bronze_empresa_4',), ('bronze_empresa_5',), ('bronze_empresa_6',), ('bronze_empresa_7',), ('bronze_empresa_8',), ('bronze_empresa_9',), ('bronze_estabelecimento_0',), ('bronze_estabelecimento_1',), ('bronze_estabelecimento_2',), ('bronze_estabelecimento_3',), ('bronze_estabelecimento_4',), ('bronze_estabelecimento_5',), ('bronze_estabelecimento_6',), ('bronze_estabelecimento_7',), ('bronze_estabelecimento_8',), ('bronze_estabelecimento_9',), ('bronze_motivo_situacao_cadastral',), ('bronze_municipio',), ('bronze_natureza_juridica',), ('bronze_pais',), ('bronze_qualificacao_socio',), ('bronze_simples',), ('bronze_socio_0',), ('bronze_socio_1',), ('bronze_socio_2',), ('bronze_socio_3',), ('bronze_socio_4',), ('bronze_socio_5',), ('bronze_socio_6',), ('bronze_socio_7',), ('bronze_socio_8',), ('bronze_socio_9',), ('dados',), ('gold_cnae',), ('gold_empresa',), ('gold_motivo_situacao_cadastral',), ('gold_natureza_juridica',), ('silver_cnae_empresa',), ('silver_empresa',), ('silver_estabelecimento',), ('teste_cnae',)]
# --------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Retorna Data Frame
#                           table_name
# 0                        bronze_cnae
# 1                   bronze_empresa_0
# 2                   bronze_empresa_1
# 3                   bronze_empresa_2
# 4                   bronze_empresa_3
# 5                   bronze_empresa_4
# 6                   bronze_empresa_5
# 7                   bronze_empresa_6
# 8                   bronze_empresa_7
# 9                   bronze_empresa_8
# 10                  bronze_empresa_9
# 11          bronze_estabelecimento_0
# 12          bronze_estabelecimento_1
# 13          bronze_estabelecimento_2
# 14          bronze_estabelecimento_3
# 15          bronze_estabelecimento_4
# 16          bronze_estabelecimento_5
# 17          bronze_estabelecimento_6
# 18          bronze_estabelecimento_7
# 19          bronze_estabelecimento_8
# 20          bronze_estabelecimento_9
# 21  bronze_motivo_situacao_cadastral
# 22                  bronze_municipio
# 23          bronze_natureza_juridica
# 24                       bronze_pais
# 25         bronze_qualificacao_socio
# 26                    bronze_simples
# 27                    bronze_socio_0
# 28                    bronze_socio_1
# 29                    bronze_socio_2
# 30                    bronze_socio_3
# 31                    bronze_socio_4
# 32                    bronze_socio_5
# 33                    bronze_socio_6
# 34                    bronze_socio_7
# 35                    bronze_socio_8
# 36                    bronze_socio_9
# 37                             dados
# 38                         gold_cnae
# 39                      gold_empresa
# 40    gold_motivo_situacao_cadastral
# 41            gold_natureza_juridica
# 42               silver_cnae_empresa
# 43                    silver_empresa
# 44            silver_estabelecimento
# 45                        teste_cnae

# %% [markdown]
# ### Select *

# %%
query = '''
    SELECT *
    FROM bronze_cnae
    '''
# com SELECT *
result_df = conn.execute(query).fetchdf()
result_df
# Out:
#        codigo                                          descricao
# 0     0111301                                   Cultivo de arroz
# 1     0111302                                   Cultivo de milho
# 2     0111303                                   Cultivo de trigo
# 3     0111399  Cultivo de outros cereais não especificados an...
# 4     0112101                        Cultivo de algodão herbáceo
# ...       ...                                                ...
# 1354  9609208      Higiene e embelezamento de animais domésticos
# 1355  9609299  Outras atividades de serviços pessoais não esp...
# 1356  9700500                                Serviços domésticos
# 1357  9900800  Organismos internacionais e outras instituiçõe...
# 1358  8888888                  Atividade Econônica não informada
#
# [1359 rows x 2 columns]

# %%
query = '''
    FROM bronze_cnae
    '''
# Sem SELECT *
result_df = conn.execute(query).fetchdf()
result_df
# Out:
#        codigo                                          descricao
# 0     0111301                                   Cultivo de arroz
# 1     0111302                                   Cultivo de milho
# 2     0111303                                   Cultivo de trigo
# 3     0111399  Cultivo de outros cereais não especificados an...
# 4     0112101                        Cultivo de algodão herbáceo
# ...       ...                                                ...
# 1354  9609208      Higiene e embelezamento de animais domésticos
# 1355  9609299  Outras atividades de serviços pessoais não esp...
# 1356  9700500                                Serviços domésticos
# 1357  9900800  Organismos internacionais e outras instituiçõe...
# 1358  8888888                  Atividade Econônica não informada
#
# [1359 rows x 2 columns]

# %% [markdown]
# ### Group By All

# %%
query = '''
    SELECT
        municipio, porte,natureza, situacacao_cadastral
    FROM gold_empresa
    -- GROUP BY municipio
    GROUP BY municipio,porte,natureza, situacacao_cadastral
    '''


# Group By com campos
result_df = conn.execute(query).fetchdf()
result_df
# Out:
#          municipio                     porte  \
# 0   BELO HORIZONTE                    DEMAIS
# 1   BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 2   BELO HORIZONTE             MICRO EMPRESA
# 3   BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 4   BELO HORIZONTE                    DEMAIS
# 5   BELO HORIZONTE                    DEMAIS
# 6   BELO HORIZONTE             MICRO EMPRESA
# 7   BELO HORIZONTE                    DEMAIS
# 8   BELO HORIZONTE                    DEMAIS
# 9   BELO HORIZONTE                    DEMAIS
# 10  BELO HORIZONTE             MICRO EMPRESA
# 11  BELO HORIZONTE             MICRO EMPRESA
# 12  BELO HORIZONTE             MICRO EMPRESA
# 13  BELO HORIZONTE                    DEMAIS
# 14  BELO HORIZONTE                    DEMAIS
# 15  BELO HORIZONTE                    DEMAIS
# 16  BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 17  BELO HORIZONTE                    DEMAIS
# 18  BELO HORIZONTE             MICRO EMPRESA
# 19  BELO HORIZONTE                    DEMAIS
# 20  BELO HORIZONTE                    DEMAIS
# 21  BELO HORIZONTE                    DEMAIS
# 22  BELO HORIZONTE                    DEMAIS
# 23  BELO HORIZONTE                    DEMAIS
# 24  BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 25  BELO HORIZONTE                    DEMAIS
# 26  BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 27  BELO HORIZONTE                    DEMAIS
# 28  BELO HORIZONTE                    DEMAIS
# 29  BELO HORIZONTE                    DEMAIS
#
#                                              natureza situacacao_cadastral
# 0                                         Cooperativa                   08
# 1   Empresa Individual de Responsabilidade Limitad...                   08
# 2                       Sociedade Empresaria Limitada                   04
# 3                          Sociedade Simples Limitada                   02
# 4                       Sociedade Empresaria Limitada                   04
# 5                           Sociedade Anonima Fechada                   08
# 6                           Sociedade Anonima Fechada                   02
# 7                           Sociedade Anonima Fechada                   01
# 8                             Consorcio de Sociedades                   08
# 9                       Sociedade Empresaria Limitada                   02
# 10                      Sociedade Empresaria Limitada                   08
# 11                      Sociedade Empresaria Limitada                   03
# 12                            Empresario (Individual)                   08
# 13                                        Cooperativa                   04
# 14                          Sociedade Anonima Fechada                   02
# 15                                    Empresa Publica                   02
# 16                      Sociedade Empresaria Limitada                   04
# 17                            Consorcio de Sociedades                   02
# 18                      Sociedade Empresaria Limitada                   02
# 19                      Sociedade Empresaria Limitada                   08
# 20                      Sociedade Empresaria Limitada                   03
# 21                         Sociedade Simples Limitada                   02
# 22  Empresa Individual de Responsabilidade Limitad...                   08
# 23                           Sociedade Anonima Aberta                   02
# 24                      Sociedade Empresaria Limitada                   08
# 25                        Sociedade de Economia Mista                   02
# 26                      Sociedade Empresaria Limitada                   02
# 27                           Sociedade Anonima Aberta                   08
# 28                           Sociedade Anonima Aberta                   03
# 29                          Sociedade Anonima Fechada                   04

# %%
query = '''
    SELECT
        municipio,porte,natureza, situacacao_cadastral
    FROM gold_empresa
    GROUP BY ALL
    '''
# Group By ALL
result_df = conn.execute(query).fetchdf()
result_df
# Out:
#          municipio                     porte  \
# 0   BELO HORIZONTE                    DEMAIS
# 1   BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 2   BELO HORIZONTE             MICRO EMPRESA
# 3   BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 4   BELO HORIZONTE                    DEMAIS
# 5   BELO HORIZONTE                    DEMAIS
# 6   BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 7   BELO HORIZONTE                    DEMAIS
# 8   BELO HORIZONTE             MICRO EMPRESA
# 9   BELO HORIZONTE                    DEMAIS
# 10  BELO HORIZONTE                    DEMAIS
# 11  BELO HORIZONTE                    DEMAIS
# 12  BELO HORIZONTE                    DEMAIS
# 13  BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 14  BELO HORIZONTE                    DEMAIS
# 15  BELO HORIZONTE                    DEMAIS
# 16  BELO HORIZONTE                    DEMAIS
# 17  BELO HORIZONTE                    DEMAIS
# 18  BELO HORIZONTE             MICRO EMPRESA
# 19  BELO HORIZONTE                    DEMAIS
# 20  BELO HORIZONTE                    DEMAIS
# 21  BELO HORIZONTE                    DEMAIS
# 22  BELO HORIZONTE             MICRO EMPRESA
# 23  BELO HORIZONTE             MICRO EMPRESA
# 24  BELO HORIZONTE             MICRO EMPRESA
# 25  BELO HORIZONTE                    DEMAIS
# 26  BELO HORIZONTE                    DEMAIS
# 27  BELO HORIZONTE                    DEMAIS
# 28  BELO HORIZONTE  EMPRESA DE PEQUENO PORTE
# 29  BELO HORIZONTE                    DEMAIS
#
#                                              natureza situacacao_cadastral
# 0                                         Cooperativa                   08
# 1   Empresa Individual de Responsabilidade Limitad...                   08
# 2                       Sociedade Empresaria Limitada                   04
# 3                          Sociedade Simples Limitada                   02
# 4   Empresa Individual de Responsabilidade Limitad...                   08
# 5                            Sociedade Anonima Aberta                   02
# 6                       Sociedade Empresaria Limitada                   08
# 7                         Sociedade de Economia Mista                   02
# 8                       Sociedade Empresaria Limitada                   02
# 9                       Sociedade Empresaria Limitada                   08
# 10                      Sociedade Empresaria Limitada                   03
# 11                         Sociedade Simples Limitada                   02
# 12                      Sociedade Empresaria Limitada                   04
# 13                      Sociedade Empresaria Limitada                   02
# 14                           Sociedade Anonima Aberta                   08
# 15                           Sociedade Anonima Aberta                   03
# 16                          Sociedade Anonima Fechada                   04
# 17                          Sociedade Anonima Fechada                   08
# 18                          Sociedade Anonima Fechada                   02
# 19                          Sociedade Anonima Fechada                   01
# 20                            Consorcio de Sociedades                   08
# 21                      Sociedade Empresaria Limitada                   02
# 22                      Sociedade Empresaria Limitada                   08
# 23                      Sociedade Empresaria Limitada                   03
# 24                            Empresario (Individual)                   08
# 25                                        Cooperativa                   04
# 26                          Sociedade Anonima Fechada                   02
# 27                                    Empresa Publica                   02
# 28                      Sociedade Empresaria Limitada                   04
# 29                            Consorcio de Sociedades                   02

# %% [markdown]
# ### Exclude

# %%
query = '''
    SELECT
        *
    FROM bronze_estabelecimento_0
    WHERE uf = 'MG'
    '''
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#   cnpj_basico cnpj_ordem cnpj_dv  identificador  \
# 0    39721458       0001      75              1
# 1    42567873       0001      20              1
# 2    30745908       0001      95              1
# 3    37349550       0001      20              1
# 4    40141968       0001      52              1
#
#                       nome_fantasia situacacao_cadastral  \
# 0                              None                   02
# 1   PIILLAR MATERIAIS DE CONSTRUCAO                   02
# 2                  HIPPER LAVA JATO                   08
# 3                       SA CLOTHING                   02
# 4  LEMAR COMERCIO E SERVICOS GERAIS                   02
#
#    data_situacao_cadastral codigo_motivo_situacao_cadastral cidade_exterior  \
# 0                 20201109                               00            None
# 1                 20210702                               00            None
# 2                 20221205                               01            None
# 3                 20200608                               00            None
# 4                 20201217                               00            None
#
#   codigo_pais  ...  municipio ddd1 telefone1  ddd2 telefone2  ddd3 telefone3  \
# 0        None  ...       4079   34  36620559    34  88543144  None      None
# 1        None  ...       4733   32  32331984  None      None  None      None
# 2        None  ...       4141   35  97665989  None      None  None      None
# 3        None  ...       5403   34  32359011  None      None  None      None
# 4        None  ...       4821   31  99187462  None      None  None      None
#
#                                      email situacao_especial  \
# 0         CONTATO@DRDPROJETOSEOBRAS.COM.BR              None
# 1                 JANETELEMPRESA@GMAIL.COM              None
# 2  OCTAVIO@LIDERCONSULTORIACONTABIL.COM.BR              None
# 3           VIRTUAL@VIRTUALSERVICOS.COM.BR              None
# 4        CARLOSHENRIQUEALVES9511@GMAIL.COM              None
#
#   data_situacao_especial
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 30 columns]

# %%
query = '''
    SELECT
        *
        EXCLUDE (cidade_exterior,codigo_pais,data_situacao_cadastral)
    FROM bronze_estabelecimento_0
    WHERE uf = 'MG'
    '''
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#   cnpj_basico cnpj_ordem cnpj_dv  identificador  \
# 0    39721458       0001      75              1
# 1    42567873       0001      20              1
# 2    30745908       0001      95              1
# 3    37349550       0001      20              1
# 4    40141968       0001      52              1
#
#                       nome_fantasia situacacao_cadastral  \
# 0                              None                   02
# 1   PIILLAR MATERIAIS DE CONSTRUCAO                   02
# 2                  HIPPER LAVA JATO                   08
# 3                       SA CLOTHING                   02
# 4  LEMAR COMERCIO E SERVICOS GERAIS                   02
#
#   codigo_motivo_situacao_cadastral  data_inicio_atividade cnae_principal  \
# 0                               00               20201109        7112000
# 1                               00               20210702        4744099
# 2                               01               20180620        4520005
# 3                               00               20200608        4781400
# 4                               00               20201217        4399103
#
#                                      cnae_secundario  ... municipio ddd1  \
# 0                                    4120400,4399103  ...      4079   34
# 1                                               None  ...      4733   32
# 2                                    4930201,5320201  ...      4141   35
# 3                                    4763602,4782201  ...      5403   34
# 4  0142300,0161003,0161099,4120400,4213800,429959...  ...      4821   31
#
#   telefone1  ddd2 telefone2  ddd3 telefone3  \
# 0  36620559    34  88543144  None      None
# 1  32331984  None      None  None      None
# 2  97665989  None      None  None      None
# 3  32359011  None      None  None      None
# 4  99187462  None      None  None      None
#
#                                      email situacao_especial  \
# 0         CONTATO@DRDPROJETOSEOBRAS.COM.BR              None
# 1                 JANETELEMPRESA@GMAIL.COM              None
# 2  OCTAVIO@LIDERCONSULTORIACONTABIL.COM.BR              None
# 3           VIRTUAL@VIRTUALSERVICOS.COM.BR              None
# 4        CARLOSHENRIQUEALVES9511@GMAIL.COM              None
#
#   data_situacao_especial
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Create Silver Estabelecimento

# %%
query = '''
    DROP TABLE IF EXISTS silver_estabelecimento
'''
conn.execute(query)

query = '''
CREATE TABLE silver_estabelecimento
AS
SELECT row_number() OVER() AS id,a.* FROM (
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_0 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_1 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_2 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_3 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_4 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_5 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_6 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_7 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_8 WHERE uf = 'MG'
	UNION
	SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_9 WHERE uf = 'MG'
) a
'''
conn.execute(query)

# %%
query = '''
	SELECT count(*) FROM silver_estabelecimento
'''
result_one = conn.execute(query).fetchone()
print("Total registros na silver_estabelecimento:", result_one[0])
# Out:
# Total registros na silver_estabelecimento: 6868222

# %%
query = '''
SELECT count(*) FROM (
	SELECT * FROM bronze_estabelecimento_0
	UNION
	SELECT * FROM bronze_estabelecimento_1
	UNION
	SELECT * FROM bronze_estabelecimento_2
	UNION
	SELECT * FROM bronze_estabelecimento_3
	UNION
	SELECT * FROM bronze_estabelecimento_4
	UNION
	SELECT * FROM bronze_estabelecimento_5
	UNION
	SELECT * FROM bronze_estabelecimento_6
	UNION
	SELECT * FROM bronze_estabelecimento_7
	UNION
	SELECT * FROM bronze_estabelecimento_8
	UNION
	SELECT * FROM bronze_estabelecimento_9
) a
'''
#result_one = conn.execute(query).fetchone()
#print("Total registros dos union :", result_one[0])
print("Levou mais de 5 minutos pra rodar e foi interrompido, por isso esta comentado")
# Out:
# Levou mais de 5 minutos pra rodar e foi interrompido, por isso esta comentado

# %%
query = '''
SELECT count(*) FROM (
	SELECT cnpj_basico FROM bronze_estabelecimento_0
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_1
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_2
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_3
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_4
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_5
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_6
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_7
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_8
	UNION
	SELECT cnpj_basico FROM bronze_estabelecimento_9
) a
'''
result_one = conn.execute(query).fetchone()
print("Total registros dos union :", result_one[0])
# Out:
# Total registros dos union : 59954864

# %% [markdown]
# #### Resultado
# Para fazer o COUNT de todos os campos cnpj_basico das tabelas bronze_estabelecimento_X, levou 49.5s - Total de Registros: 59.954.864
#
# Para fazer o COUNT de todos os registros (*) das tabelas bronze_estabelecimento_X rodou por mais de 5 minutos e parei o processo
#
# Para criar a nova tabela com os registros das tabelas bronze_estabelecimento_X, filtrados pelo estado, levou 2min e 38s - Total de Registros: 6.868.222

# %% [markdown]
# ### SILVER

# %%
query = '''
    CREATE OR REPLACE TABLE silver_empresa
    AS
    SELECT row_number() OVER() AS id,a.* FROM (
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_0
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_1
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_2
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_3
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_4
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_5
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_6
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_7
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_8
        UNION
        SELECT * EXCLUDE (ente_federativo) FROM bronze_empresa_9
    ) a
    WHERE a.cnpj_basico IN (
        SELECT cnpj_basico FROM silver_estabelecimento
    )
'''
conn.execute(query)

# %%
query = 'SELECT count(*) FROM silver_estabelecimento'
result_one = conn.execute(query).fetchone()
print(f'silver_estabelecimento: {result_one[0]:,.0f}')

query = 'SELECT COUNT(*) FROM silver_empresa'
result_one = conn.execute(query).fetchone()
print(f'silver_empresa: {result_one[0]:,.0f}')
# Out:
# silver_estabelecimento: 6,868,222
# silver_empresa: 6,596,430

# %% [markdown]
# ### GOLD

# %%
query = 'DROP TABLE IF EXISTS gold_empresa'
conn.execute(query)

query = '''
    CREATE TABLE gold_empresa
    AS
    SELECT
        DISTINCT
        TRANSLATE (
        bm.descricao,
    'ŠŽšžŸÁÇÉÍÓÚÀÈÌÒÙÂÊÎÔÛÃÕËÜÏÖÑÝåáçéíóúàèìòùâêîôûãõëüïöñýÿ',
        'SZszYACEIOUAEIOUAEIOUAOEUIONYaaceiouaeiouaeiouaoeuionyy')
        as municipio,
        CONCAT(se.cnpj_basico,se.cnpj_ordem,se.cnpj_dv) cnpj,
        sem.*,
        CONCAT(SUBSTR(CAST(se.data_situacao_cadastral as VARCHAR), 1, 4),'-',
        SUBSTR(CAST(se.data_situacao_cadastral as VARCHAR), 5, 2),'-',
        SUBSTR(CAST(se.data_situacao_cadastral as VARCHAR), 7, 2)) AS data_situacao,
        CONCAT(SUBSTR(CAST(se.data_inicio_atividade as VARCHAR), 1, 4),'-',
        SUBSTR(CAST(se.data_inicio_atividade as VARCHAR), 5, 2),'-',
        SUBSTR(CAST(se.data_inicio_atividade as VARCHAR), 7, 2)) AS data_inicio,
        TRANSLATE (
        se.bairro,
    'ŠŽšžŸÁÇÉÍÓÚÀÈÌÒÙÂÊÎÔÛÃÕËÜÏÖÑÝåáçéíóúàèìòùâêîôûãõëüïöñýÿ',
        'SZszYACEIOUAEIOUAEIOUAOEUIONYaaceiouaeiouaeiouaoeuionyy')
        as bairros,
        CASE
            WHEN sem.porte_empresa = '00' THEN 'NAO INFORMADO'
            WHEN sem.porte_empresa = '01' THEN 'MICRO EMPRESA'
            WHEN sem.porte_empresa = '03' THEN 'EMPRESA DE PEQUENO PORTE'
            WHEN sem.porte_empresa = '05' THEN 'DEMAIS'
            ELSE ''
        END as porte,
        TRANSLATE (
        bn.descricao,
    'ŠŽšžŸÁÇÉÍÓÚÀÈÌÒÙÂÊÎÔÛÃÕËÜÏÖÑÝåáçéíóúàèìòùâêîôûãõëüïöñýÿ',
        'SZszYACEIOUAEIOUAEIOUAOEUIONYaaceiouaeiouaeiouaoeuionyy')
        as natureza,
        CASE
            WHEN sem.porte_empresa = '01' THEN 'NULA'
            WHEN sem.porte_empresa = '2' THEN 'ATIVA'
            WHEN sem.porte_empresa = '3' THEN 'SUSPENSA'
            WHEN sem.porte_empresa = '4' THEN 'INAPTA'
            WHEN sem.porte_empresa = '08' THEN 'BAIXADA'
            ELSE ''
        END as situacao,
        se.*
        EXCLUDE(
            municipio,cnpj_basico,cnpj_ordem,cnpj_dv,
            ddd1,ddd2,ddd3,telefone1,telefone2,telefone3,
            cnae_principal,cnae_secundario,
            situacao_especial,data_situacao_especial,
            tipo_logradouro,logradouro,numero,complemento,
            uf,email,data_situacao_cadastral,data_inicio_atividade,bairro
        )
    FROM silver_empresa sem
    INNER JOIN silver_estabelecimento se ON sem.cnpj_basico = se.cnpj_basico
    INNER JOIN silver_cnae_empresa sc ON se.cnpj_basico = sc.cnpj_basico
    INNER JOIN bronze_cnae bc ON sc.cnae = bc.codigo
    INNER JOIN bronze_municipio bm ON se.municipio = bm.codigo
    INNER JOIN bronze_natureza_juridica bn ON sem.natureza_juridica = bn.codigo
    WHERE
        bm.descricao = 'BELO HORIZONTE'
        AND (
            bc.descricao LIKE '% dados%' OR
            bc.descricao LIKE '%informá%' OR
            bc.descricao LIKE '%softw%' OR
            bc.descricao LIKE '%programa%' OR
            bc.descricao LIKE '%comput%' OR
            bc.descricao LIKE '%telecom%' OR
            bc.descricao LIKE '%proved%'
        )

'''
conn.execute(query)


query = "SELECT * FROM gold_empresa"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#         municipio            cnpj       id cnpj_basico  \
# 0  BELO HORIZONTE  45242914026678  2003132    45242914
# 1  BELO HORIZONTE  45242914033534  2003132    45242914
# 2  BELO HORIZONTE  01279782000889  2023015    01279782
# 3  BELO HORIZONTE  00776574085127  2025186    00776574
# 4  BELO HORIZONTE  00776574042746  2025186    00776574
#
#                                razao_social  natureza_juridica  \
# 0                            C&A MODAS S.A.               2046
# 1                            C&A MODAS S.A.               2046
# 2     ENGEMON IT TECNOLOGIA E SERVICOS LTDA               2062
# 3  AMERICANAS S.A - EM RECUPERACAO JUDICIAL               2046
# 4  AMERICANAS S.A - EM RECUPERACAO JUDICIAL               2046
#
#   qualificacao_responsavel  capital_social porte_empresa data_situacao  ...  \
# 0                       10   1849418624,00            05    2011-08-16  ...
# 1                       10   1849418624,00            05    2017-06-22  ...
# 2                       05      1800000,00            05    2024-01-23  ...
# 3                       64  39918251652,38            05    2021-05-03  ...
# 4                       64  39918251652,38            05    2021-02-24  ...
#
#             bairros   porte                       natureza situacao     id_1  \
# 0       VILA CLORIS  DEMAIS       Sociedade Anonima Aberta           6047894
# 1        VENDA NOVA  DEMAIS       Sociedade Anonima Aberta           5126925
# 2           LOURDES  DEMAIS  Sociedade Empresaria Limitada           4842139
# 3           GUARANI  DEMAIS       Sociedade Anonima Aberta           1180681
# 4  JARDIM ATLANTICO  DEMAIS       Sociedade Anonima Aberta           1190274
#
#    identificador  nome_fantasia situacacao_cadastral  \
# 0              2      C&A MODAS                   02
# 1              2      C&A MODAS                   08
# 2              2           None                   02
# 3              2    FILIAL 5083                   02
# 4              2           None                   02
#
#   codigo_motivo_situacao_cadastral       cep
# 0                               00  31744007
# 1                               01  31615310
# 2                               00  30170911
# 3                               00  31814620
# 4                               00  31560000
#
# [5 rows x 21 columns]

# %%
query = 'SELECT * FROM bronze_municipio'
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#   codigo                descricao
# 0   0001            GUAJARA-MIRIM
# 1   0002  ALTO ALEGRE DOS PARECIS
# 2   0003              PORTO VELHO
# 3   0004                  BURITIS
# 4   0005                JI-PARANA

# %% [markdown]
# ### Select PARQUET

# %%
query = f"SELECT * FROM 'C:/ProfDaniloSantos/cnpj/dados/bronze/cnae.parquet'"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#     codigo                                          descricao
# 0  0111301                                   Cultivo de arroz
# 1  0111302                                   Cultivo de milho
# 2  0111303                                   Cultivo de trigo
# 3  0111399  Cultivo de outros cereais não especificados an...
# 4  0112101                        Cultivo de algodão herbáceo

# %% [markdown]
# ### Select Multiplos parquet's

# %%
query0 = f"SELECT count(*) total FROM 'C:/ProfDaniloSantos/cnpj/dados/bronze/estabelecimento_0.parquet'"
query1 = f"SELECT count(*) total FROM 'C:/ProfDaniloSantos/cnpj/dados/bronze/estabelecimento_1.parquet'"
query2 = f"SELECT count(*) total FROM 'C:/ProfDaniloSantos/cnpj/dados/bronze/estabelecimento_2.parquet'"
query = f'''
    SELECT SUM(a.total)
    FROM (
        {query0}
        UNION ALL
        {query1}
        UNION ALL
        {query2}
    ) a
'''
result_one = conn.execute(query).fetchone()
print("Total registros na estabelecimento_0/1/2.parquet:", result_one[0])
# Out:
# Total registros na estabelecimento_0/1/2.parquet: 29709621

# %%
# Gravação no formato Parquet
query = f"SELECT count(*) total FROM 'C:/ProfDaniloSantos/cnpj/dados/bronze/estabelecimento_*.parquet'"
result_one = conn.execute(query).fetchone()
print("Total registros na estabelecimento_*.parquet:", result_one[0])
# Out:
# Total registros na estabelecimento_*.parquet: 62983662

# %% [markdown]
# ### Select CSV

# %%
query = f"SELECT * FROM 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.csv' WHERE municipio = 'BELO HORIZONTE'"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#         municipio            cnpj       id cnpj_basico  \
# 0  BELO HORIZONTE  45242914026678  2003132    45242914
# 1  BELO HORIZONTE  45242914033534  2003132    45242914
# 2  BELO HORIZONTE  01279782000889  2023015    01279782
# 3  BELO HORIZONTE  00776574085127  2025186    00776574
# 4  BELO HORIZONTE  00776574042746  2025186    00776574
#
#                                razao_social  natureza_juridica  \
# 0                            C&A MODAS S.A.               2046
# 1                            C&A MODAS S.A.               2046
# 2     ENGEMON IT TECNOLOGIA E SERVICOS LTDA               2062
# 3  AMERICANAS S.A - EM RECUPERACAO JUDICIAL               2046
# 4  AMERICANAS S.A - EM RECUPERACAO JUDICIAL               2046
#
#   qualificacao_responsavel  capital_social porte_empresa data_situacao  ...  \
# 0                       10   1849418624,00            05    2011-08-16  ...
# 1                       10   1849418624,00            05    2017-06-22  ...
# 2                       05      1800000,00            05    2024-01-23  ...
# 3                       64  39918251652,38            05    2021-05-03  ...
# 4                       64  39918251652,38            05    2021-02-24  ...
#
#             bairros   porte                       natureza situacao     id_1  \
# 0       VILA CLORIS  DEMAIS       Sociedade Anonima Aberta     None  6047894
# 1        VENDA NOVA  DEMAIS       Sociedade Anonima Aberta     None  5126925
# 2           LOURDES  DEMAIS  Sociedade Empresaria Limitada     None  4842139
# 3           GUARANI  DEMAIS       Sociedade Anonima Aberta     None  1180681
# 4  JARDIM ATLANTICO  DEMAIS       Sociedade Anonima Aberta     None  1190274
#
#    identificador  nome_fantasia situacacao_cadastral  \
# 0              2      C&A MODAS                   02
# 1              2      C&A MODAS                   08
# 2              2           None                   02
# 3              2    FILIAL 5083                   02
# 4              2           None                   02
#
#   codigo_motivo_situacao_cadastral       cep
# 0                               00  31744007
# 1                               01  31615310
# 2                               00  30170911
# 3                               00  31814620
# 4                               00  31560000
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Describe

# %%
#Describe da Tabela
query = f"DESCRIBE gold_empresa"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#     column_name column_type null   key default extra
# 0     municipio     VARCHAR  YES  None    None  None
# 1          cnpj     VARCHAR  YES  None    None  None
# 2            id      BIGINT  YES  None    None  None
# 3   cnpj_basico     VARCHAR  YES  None    None  None
# 4  razao_social     VARCHAR  YES  None    None  None

# %%
#Describe do select
query = f"DESCRIBE SELECT municipio, cnpj,id FROM gold_empresa"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#   column_name column_type null   key default extra
# 0   municipio     VARCHAR  YES  None    None  None
# 1        cnpj     VARCHAR  YES  None    None  None
# 2          id      BIGINT  YES  None    None  None

# %%
#Describe do arquivo
query = f"DESCRIBE SELECT * FROM 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.csv'"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#     column_name column_type null   key default extra
# 0     municipio     VARCHAR  YES  None    None  None
# 1          cnpj     VARCHAR  YES  None    None  None
# 2            id      BIGINT  YES  None    None  None
# 3   cnpj_basico     VARCHAR  YES  None    None  None
# 4  razao_social     VARCHAR  YES  None    None  None

# %% [markdown]
# ### Summarize

# %%
#Summarize da Tabela
query = f"SUMMARIZE gold_empresa"
result_df = conn.execute(query).fetchdf()
result_df#.head()
# Out:
#                          column_name column_type  \
# 0                          municipio     VARCHAR
# 1                               cnpj     VARCHAR
# 2                                 id      BIGINT
# 3                        cnpj_basico     VARCHAR
# 4                       razao_social     VARCHAR
# 5                  natureza_juridica      BIGINT
# 6           qualificacao_responsavel     VARCHAR
# 7                     capital_social     VARCHAR
# 8                      porte_empresa     VARCHAR
# 9                      data_situacao     VARCHAR
# 10                       data_inicio     VARCHAR
# 11                           bairros     VARCHAR
# 12                             porte     VARCHAR
# 13                          natureza     VARCHAR
# 14                          situacao     VARCHAR
# 15                              id_1      BIGINT
# 16                     identificador      BIGINT
# 17                     nome_fantasia     VARCHAR
# 18              situacacao_cadastral     VARCHAR
# 19  codigo_motivo_situacao_cadastral     VARCHAR
# 20                               cep     VARCHAR
#
#                                                   min  \
# 0                                      BELO HORIZONTE
# 1                                      00085885000179
# 2                                               30244
# 3                                            00085885
# 4   2ELETRO COMERCIO E DISTRIBUICAO DE PRODUTOS DE...
# 5                                                2011
# 6                                                  05
# 7                                                0,00
# 8                                                  01
# 9                                                 0--
# 10                                         1966-07-07
# 11                                       FUNCIONARIOS
# 12                                             DEMAIS
# 13                            Consorcio de Sociedades
# 14
# 15                                               3933
# 16                                                  1
# 17                                            2ELETRO
# 18                                                 01
# 19                                                 00
# 20                                           30110005
#
#                                   max  approx_unique                 avg  \
# 0                      BELO HORIZONTE              1                None
# 1                      96534094001049           1043                None
# 2                             6594454            577    3345444.97741433
# 3                            96534094            550                None
# 4   ZOPONE ENGENHARIA E COMERCIO LTDA            483                None
# 5                                2305             11  2058.5334890965732
# 6                                  65              7                None
# 7                            99800,00            296                None
# 8                                  05              3                None
# 9                          2024-10-07            914                None
# 10                         2024-10-07            958                None
# 11                            VITORIA            181                None
# 12                      MICRO EMPRESA              3                None
# 13        Sociedade de Economia Mista             10                None
# 14                               NULA              2                None
# 15                            6864188           1566  3364167.2718068534
# 16                                  2              2  1.8901869158878504
# 17                         ZOOM GROUP            326                None
# 18                                 08              5                None
# 19                                 74             17                None
# 20                           31995150            599                None
#
#                     std      q25      q50      q75  count  null_percentage
# 0                  None     None     None     None   1284             0.00
# 1                  None     None     None     None   1284             0.00
# 2     1972668.053061459  1760237  2912841  5425499   1284             0.00
# 3                  None     None     None     None   1284             0.00
# 4                  None     None     None     None   1284             0.00
# 5    18.959808168191703     2054     2058     2062   1284             0.00
# 6                  None     None     None     None   1284             0.00
# 7                  None     None     None     None   1284             0.00
# 8                  None     None     None     None   1284             0.00
# 9                  None     None     None     None   1284             0.00
# 10                 None     None     None     None   1284             0.00
# 11                 None     None     None     None   1284             0.31
# 12                 None     None     None     None   1284             0.00
# 13                 None     None     None     None   1284             0.00
# 14                 None     None     None     None   1284             0.00
# 15   1954599.7996163252  1652098  3327216  5027036   1284             0.00
# 16  0.31277845600530974        2        2        2   1284             0.00
# 17                 None     None     None     None   1284            66.82
# 18                 None     None     None     None   1284             0.00
# 19                 None     None     None     None   1284             0.00
# 20                 None     None     None     None   1284             0.00

# %%
#Summarize do select
query = f"SUMMARIZE SELECT municipio, cnpj,id FROM gold_empresa"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#   column_name column_type             min             max  approx_unique  \
# 0   municipio     VARCHAR  BELO HORIZONTE  BELO HORIZONTE              1
# 1        cnpj     VARCHAR  00085885000179  96534094001049           1043
# 2          id      BIGINT           30244         6594454            577
#
#                 avg                std      q25      q50      q75  count  \
# 0              None               None     None     None     None   1284
# 1              None               None     None     None     None   1284
# 2  3345444.97741433  1972668.053061459  1760237  2912841  5425499   1284
#
#    null_percentage
# 0              0.0
# 1              0.0
# 2              0.0

# %%
#Summarize do arquivo
query = f"SUMMARIZE SELECT * FROM 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.csv'"
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#     column_name column_type  \
# 0     municipio     VARCHAR
# 1          cnpj     VARCHAR
# 2            id      BIGINT
# 3   cnpj_basico     VARCHAR
# 4  razao_social     VARCHAR
#
#                                                  min  \
# 0                                     BELO HORIZONTE
# 1                                     00085885000179
# 2                                              30244
# 3                                           00085885
# 4  2ELETRO COMERCIO E DISTRIBUICAO DE PRODUTOS DE...
#
#                                  max  approx_unique               avg  \
# 0                     BELO HORIZONTE              1              None
# 1                     96534094001049           1043              None
# 2                            6594454            577  3345444.97741433
# 3                           96534094            550              None
# 4  ZOPONE ENGENHARIA E COMERCIO LTDA            483              None
#
#                  std      q25      q50      q75  count  null_percentage
# 0               None     None     None     None   1284              0.0
# 1               None     None     None     None   1284              0.0
# 2  1972668.053061459  1760237  2912841  5425499   1284              0.0
# 3               None     None     None     None   1284              0.0
# 4               None     None     None     None   1284              0.0

# %% [markdown]
# ### Import Arquivo

# %%
query = f"CREATE TABLE teste_cnae AS SELECT * FROM './dados/bronze/cnae.parquet' "
conn.execute(query)
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# Cell In[33], line 2
#       1 query = f"CREATE TABLE teste_cnae AS SELECT * FROM './dados/bronze/cnae.parquet' "
# ----> 2 conn.execute(query)
#
# CatalogException: Catalog Error: Table with name "teste_cnae" already exists!

# %%
query = f"DROP TABLE IF EXISTS teste_cnae"
conn.execute(query)

query = f"CREATE TABLE teste_cnae AS SELECT * FROM './dados/bronze/cnae.parquet' "
conn.execute(query)

# %%
query = f"CREATE OR REPLACE TABLE teste_cnae AS SELECT * FROM './dados/bronze/cnae.parquet' "
conn.execute(query)

# %% [markdown]
# ### Exportar Arquivo

# %%
query = '''
    COPY
	(SELECT * FROM gold_empresa)
	TO 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.csv'
	(DELIMITER ';', HEADER);
'''
conn.execute(query)

# %%
query = '''
    COPY
	(SELECT * FROM gold_empresa)
	TO 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.parquet'
    ;
'''
conn.execute(query)

# %% [markdown]
# ### API Relacional

# %%
df = conn.sql("SELECT * FROM gold_empresa")
df.show()
# Out:
# ┌────────────────┬────────────────┬─────────┬─────────────┬──────────────────────────────────────────┬───────────────────┬──────────────────────────┬────────────────┬───────────────┬───────────────┬─────────────┬──────────────────┬─────────┬───────────────────────────────┬──────────┬─────────┬───────────────┬───────────────┬──────────────────────┬──────────────────────────────────┬──────────┐
# │   municipio    │      cnpj      │   id    │ cnpj_basico │               razao_social               │ natureza_juridica │ qualificacao_responsavel │ capital_social │ porte_empresa │ data_situacao │ data_inicio │     bairros      │  porte  │           natureza            │ situacao │  id_1   │ identificador │ nome_fantasia │ situacacao_cadastral │ codigo_motivo_situacao_cadastral │   cep    │
# │    varchar     │    varchar     │  int64  │   varchar   │                 varchar                  │       int64       │         varchar          │    varchar     │    varchar    │    varchar    │   varchar   │     varchar      │ varchar │            varchar            │ varchar  │  int64  │     int64     │    varchar    │       varchar        │             varchar              │ varchar  │
# ├────────────────┼────────────────┼─────────┼─────────────┼──────────────────────────────────────────┼───────────────────┼──────────────────────────┼────────────────┼───────────────┼───────────────┼─────────────┼──────────────────┼─────────┼───────────────────────────────┼──────────┼─────────┼───────────────┼───────────────┼──────────────────────┼──────────────────────────────────┼──────────┤
# │ BELO HORIZONTE │ 45242914026678 │ 2003132 │ 45242914    │ C&A MODAS S.A.                           │              2046 │ 10                       │ 1849418624,00  │ 05            │ 2011-08-16    │ 2011-08-16  │ VILA CLORIS      │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 6047894 │             2 │ C&A MODAS     │ 02                   │ 00                               │ 31744007 │
# │ BELO HORIZONTE │ 45242914033534 │ 2003132 │ 45242914    │ C&A MODAS S.A.                           │              2046 │ 10                       │ 1849418624,00  │ 05            │ 2017-06-22    │ 2013-12-06  │ VENDA NOVA       │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 5126925 │             2 │ C&A MODAS     │ 08                   │ 01                               │ 31615310 │
# │ BELO HORIZONTE │ 01279782000889 │ 2023015 │ 01279782    │ ENGEMON IT TECNOLOGIA E SERVICOS LTDA    │              2062 │ 05                       │ 1800000,00     │ 05            │ 2024-01-23    │ 2024-01-23  │ LOURDES          │ DEMAIS  │ Sociedade Empresaria Limitada │          │ 4842139 │             2 │ NULL          │ 02                   │ 00                               │ 30170911 │
# │ BELO HORIZONTE │ 00776574085127 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ GUARANI          │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1180681 │             2 │ FILIAL 5083   │ 02                   │ 00                               │ 31814620 │
# │ BELO HORIZONTE │ 00776574042746 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-02-24    │ 2021-02-24  │ JARDIM ATLANTICO │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1190274 │             2 │ NULL          │ 02                   │ 00                               │ 31560000 │
# │ BELO HORIZONTE │ 00776574049830 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-03-29    │ 2021-03-29  │ GUTIERREZ        │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 2111655 │             2 │ NULL          │ 02                   │ 00                               │ 30441014 │
# │ BELO HORIZONTE │ 00776574084660 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ BARREIRO         │ DEMAIS  │ Sociedade Anonima Aberta      │          │  569955 │             2 │ FILIAL 637    │ 02                   │ 00                               │ 30640000 │
# │ BELO HORIZONTE │ 00776574084589 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ SANTA HELENA     │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1774045 │             2 │ FILIAL 939    │ 02                   │ 00                               │ 30644000 │
# │ BELO HORIZONTE │ 00776574111225 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2023-03-29    │ 2021-05-20  │ BURITIS          │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1461933 │             2 │ FILIAL 630    │ 08                   │ 01                               │ 30455610 │
# │ BELO HORIZONTE │ 00776574049910 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-03-29    │ 2021-03-29  │ CENTRO           │ DEMAIS  │ Sociedade Anonima Aberta      │          │  190849 │             2 │ NULL          │ 02                   │ 00                               │ 30170131 │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │ BELO HORIZONTE │ 01928075020044 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2020-12-30    │ 2020-12-30  │ SAO PEDRO        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 5083654 │             2 │ NULL          │ 02                   │ 00                               │ 30330062 │
# │ BELO HORIZONTE │ 01928075000604 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 1997-07-18  │ LIBERDADE        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 2454858 │             2 │ NULL          │ 02                   │ 00                               │ 31270310 │
# │ BELO HORIZONTE │ 01928075003204 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2000-12-12  │ RENASCENCA       │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 6513681 │             2 │ NULL          │ 02                   │ 00                               │ 31140650 │
# │ BELO HORIZONTE │ 01928075004278 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2002-04-19  │ CAICARA          │ DEMAIS  │ Sociedade Anonima Fechada     │          │  825720 │             2 │ NULL          │ 02                   │ 00                               │ 30720340 │
# │ BELO HORIZONTE │ 01928075009741 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2006-11-01    │ 2006-11-01  │ CENTRO           │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 6838971 │             2 │ NULL          │ 02                   │ 00                               │ 30130001 │
# │ BELO HORIZONTE │ 01928075004782 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2002-04-19  │ SANTA MONICA     │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 4091820 │             2 │ NULL          │ 02                   │ 00                               │ 31530300 │
# │ BELO HORIZONTE │ 01928075014079 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2017-03-15    │ 2017-03-15  │ PADRE EUSTAQUIO  │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 5598227 │             2 │ NULL          │ 02                   │ 00                               │ 30720230 │
# │ BELO HORIZONTE │ 01928075018309 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2020-05-20    │ 2020-05-20  │ SAO PEDRO        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 1603759 │             2 │ NULL          │ 02                   │ 00                               │ 30330062 │
# │ BELO HORIZONTE │ 01928075002496 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 1998-12-11  │ SANTA TEREZINHA  │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 2704002 │             2 │ NULL          │ 02                   │ 00                               │ 31360000 │
# │ BELO HORIZONTE │ 02168225000772 │ 5768132 │ 02168225    │ GVI PROMOTORA DE VENDAS E SERVICOS LTDA  │              2062 │ 05                       │ 449121600,00   │ 05            │ 2010-12-31    │ 2006-07-07  │ FUNCIONARIOS     │ DEMAIS  │ Sociedade Empresaria Limitada │          │ 5617575 │             2 │ NULL          │ 08                   │ 02                               │ 30140003 │
# ├────────────────┴────────────────┴─────────┴─────────────┴──────────────────────────────────────────┴───────────────────┴──────────────────────────┴────────────────┴───────────────┴───────────────┴─────────────┴──────────────────┴─────────┴───────────────────────────────┴──────────┴─────────┴───────────────┴───────────────┴──────────────────────┴──────────────────────────────────┴──────────┤
# │ 1284 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                         21 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
conn.sql("SELECT * FROM gold_empresa").show()
# Out:
# ┌────────────────┬────────────────┬─────────┬─────────────┬──────────────────────────────────────────┬───────────────────┬──────────────────────────┬────────────────┬───────────────┬───────────────┬─────────────┬──────────────────┬─────────┬───────────────────────────────┬──────────┬─────────┬───────────────┬───────────────┬──────────────────────┬──────────────────────────────────┬──────────┐
# │   municipio    │      cnpj      │   id    │ cnpj_basico │               razao_social               │ natureza_juridica │ qualificacao_responsavel │ capital_social │ porte_empresa │ data_situacao │ data_inicio │     bairros      │  porte  │           natureza            │ situacao │  id_1   │ identificador │ nome_fantasia │ situacacao_cadastral │ codigo_motivo_situacao_cadastral │   cep    │
# │    varchar     │    varchar     │  int64  │   varchar   │                 varchar                  │       int64       │         varchar          │    varchar     │    varchar    │    varchar    │   varchar   │     varchar      │ varchar │            varchar            │ varchar  │  int64  │     int64     │    varchar    │       varchar        │             varchar              │ varchar  │
# ├────────────────┼────────────────┼─────────┼─────────────┼──────────────────────────────────────────┼───────────────────┼──────────────────────────┼────────────────┼───────────────┼───────────────┼─────────────┼──────────────────┼─────────┼───────────────────────────────┼──────────┼─────────┼───────────────┼───────────────┼──────────────────────┼──────────────────────────────────┼──────────┤
# │ BELO HORIZONTE │ 45242914026678 │ 2003132 │ 45242914    │ C&A MODAS S.A.                           │              2046 │ 10                       │ 1849418624,00  │ 05            │ 2011-08-16    │ 2011-08-16  │ VILA CLORIS      │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 6047894 │             2 │ C&A MODAS     │ 02                   │ 00                               │ 31744007 │
# │ BELO HORIZONTE │ 45242914033534 │ 2003132 │ 45242914    │ C&A MODAS S.A.                           │              2046 │ 10                       │ 1849418624,00  │ 05            │ 2017-06-22    │ 2013-12-06  │ VENDA NOVA       │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 5126925 │             2 │ C&A MODAS     │ 08                   │ 01                               │ 31615310 │
# │ BELO HORIZONTE │ 01279782000889 │ 2023015 │ 01279782    │ ENGEMON IT TECNOLOGIA E SERVICOS LTDA    │              2062 │ 05                       │ 1800000,00     │ 05            │ 2024-01-23    │ 2024-01-23  │ LOURDES          │ DEMAIS  │ Sociedade Empresaria Limitada │          │ 4842139 │             2 │ NULL          │ 02                   │ 00                               │ 30170911 │
# │ BELO HORIZONTE │ 00776574085127 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ GUARANI          │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1180681 │             2 │ FILIAL 5083   │ 02                   │ 00                               │ 31814620 │
# │ BELO HORIZONTE │ 00776574042746 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-02-24    │ 2021-02-24  │ JARDIM ATLANTICO │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1190274 │             2 │ NULL          │ 02                   │ 00                               │ 31560000 │
# │ BELO HORIZONTE │ 00776574049830 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-03-29    │ 2021-03-29  │ GUTIERREZ        │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 2111655 │             2 │ NULL          │ 02                   │ 00                               │ 30441014 │
# │ BELO HORIZONTE │ 00776574084660 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ BARREIRO         │ DEMAIS  │ Sociedade Anonima Aberta      │          │  569955 │             2 │ FILIAL 637    │ 02                   │ 00                               │ 30640000 │
# │ BELO HORIZONTE │ 00776574084589 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-05-03    │ 2021-05-03  │ SANTA HELENA     │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1774045 │             2 │ FILIAL 939    │ 02                   │ 00                               │ 30644000 │
# │ BELO HORIZONTE │ 00776574111225 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2023-03-29    │ 2021-05-20  │ BURITIS          │ DEMAIS  │ Sociedade Anonima Aberta      │          │ 1461933 │             2 │ FILIAL 630    │ 08                   │ 01                               │ 30455610 │
# │ BELO HORIZONTE │ 00776574049910 │ 2025186 │ 00776574    │ AMERICANAS S.A - EM RECUPERACAO JUDICIAL │              2046 │ 64                       │ 39918251652,38 │ 05            │ 2021-03-29    │ 2021-03-29  │ CENTRO           │ DEMAIS  │ Sociedade Anonima Aberta      │          │  190849 │             2 │ NULL          │ 02                   │ 00                               │ 30170131 │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │       ·        │       ·        │    ·    │    ·        │           ·                              │                ·  │ ·                        │      ·         │ ·             │     ·         │     ·       │   ·              │   ·     │            ·                  │    ·     │     ·   │             · │  ·            │ ·                    │ ·                                │    ·     │
# │ BELO HORIZONTE │ 01928075020044 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2020-12-30    │ 2020-12-30  │ SAO PEDRO        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 5083654 │             2 │ NULL          │ 02                   │ 00                               │ 30330062 │
# │ BELO HORIZONTE │ 01928075000604 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 1997-07-18  │ LIBERDADE        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 2454858 │             2 │ NULL          │ 02                   │ 00                               │ 31270310 │
# │ BELO HORIZONTE │ 01928075003204 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2000-12-12  │ RENASCENCA       │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 6513681 │             2 │ NULL          │ 02                   │ 00                               │ 31140650 │
# │ BELO HORIZONTE │ 01928075004278 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2002-04-19  │ CAICARA          │ DEMAIS  │ Sociedade Anonima Fechada     │          │  825720 │             2 │ NULL          │ 02                   │ 00                               │ 30720340 │
# │ BELO HORIZONTE │ 01928075009741 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2006-11-01    │ 2006-11-01  │ CENTRO           │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 6838971 │             2 │ NULL          │ 02                   │ 00                               │ 30130001 │
# │ BELO HORIZONTE │ 01928075004782 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 2002-04-19  │ SANTA MONICA     │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 4091820 │             2 │ NULL          │ 02                   │ 00                               │ 31530300 │
# │ BELO HORIZONTE │ 01928075014079 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2017-03-15    │ 2017-03-15  │ PADRE EUSTAQUIO  │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 5598227 │             2 │ NULL          │ 02                   │ 00                               │ 30720230 │
# │ BELO HORIZONTE │ 01928075018309 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2020-05-20    │ 2020-05-20  │ SAO PEDRO        │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 1603759 │             2 │ NULL          │ 02                   │ 00                               │ 30330062 │
# │ BELO HORIZONTE │ 01928075002496 │ 5734442 │ 01928075    │ DMA DISTRIBUIDORA S/A                    │              2054 │ 10                       │ 337192000,00   │ 05            │ 2005-03-19    │ 1998-12-11  │ SANTA TEREZINHA  │ DEMAIS  │ Sociedade Anonima Fechada     │          │ 2704002 │             2 │ NULL          │ 02                   │ 00                               │ 31360000 │
# │ BELO HORIZONTE │ 02168225000772 │ 5768132 │ 02168225    │ GVI PROMOTORA DE VENDAS E SERVICOS LTDA  │              2062 │ 05                       │ 449121600,00   │ 05            │ 2010-12-31    │ 2006-07-07  │ FUNCIONARIOS     │ DEMAIS  │ Sociedade Empresaria Limitada │          │ 5617575 │             2 │ NULL          │ 08                   │ 02                               │ 30140003 │
# ├────────────────┴────────────────┴─────────┴─────────────┴──────────────────────────────────────────┴───────────────────┴──────────────────────────┴────────────────┴───────────────┴───────────────┴─────────────┴──────────────────┴─────────┴───────────────────────────────┴──────────┴─────────┴───────────────┴───────────────┴──────────────────────┴──────────────────────────────────┴──────────┤
# │ 1284 rows (20 shown)                                                                                                                                                                                                                                                                                                                                                                         21 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df = conn.sql("SELECT * FROM gold_empresa")
df.filter("porte_empresa = '01'").limit(10).show()
# Out:
# ┌────────────────┬────────────────┬─────────┬─────────────┬──────────────────────────────────────────────────────────┬───────────────────┬──────────────────────────┬────────────────┬───────────────┬───────────────┬─────────────┬───────────────┬───────────────┬───────────────────────────────┬──────────┬─────────┬───────────────┬─────────────────────────────┬──────────────────────┬──────────────────────────────────┬──────────┐
# │   municipio    │      cnpj      │   id    │ cnpj_basico │                       razao_social                       │ natureza_juridica │ qualificacao_responsavel │ capital_social │ porte_empresa │ data_situacao │ data_inicio │    bairros    │     porte     │           natureza            │ situacao │  id_1   │ identificador │        nome_fantasia        │ situacacao_cadastral │ codigo_motivo_situacao_cadastral │   cep    │
# │    varchar     │    varchar     │  int64  │   varchar   │                         varchar                          │       int64       │         varchar          │    varchar     │    varchar    │    varchar    │   varchar   │    varchar    │    varchar    │            varchar            │ varchar  │  int64  │     int64     │           varchar           │       varchar        │             varchar              │ varchar  │
# ├────────────────┼────────────────┼─────────┼─────────────┼──────────────────────────────────────────────────────────┼───────────────────┼──────────────────────────┼────────────────┼───────────────┼───────────────┼─────────────┼───────────────┼───────────────┼───────────────────────────────┼──────────┼─────────┼───────────────┼─────────────────────────────┼──────────────────────┼──────────────────────────────────┼──────────┤
# │ BELO HORIZONTE │ 52620711000243 │  293711 │ 52620711    │ JET DISTRIBUIDORA LTDA                                   │              2062 │ 49                       │ 100000,00      │ 01            │ 2024-03-28    │ 2024-03-28  │ SANTA CRUZ    │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │  406505 │             2 │ JET DISTRIBUIDORA           │ 02                   │ 00                               │ 31155070 │
# │ BELO HORIZONTE │ 90722323007356 │  351079 │ 90722323    │ DATA CONTROL COMERCIO E SERVICOS EM INFORMATICA LTDA     │              2062 │ 49                       │ 0,00           │ 01            │ 1997-07-11    │ 1996-01-24  │ DE LOURDES    │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 3005965 │             2 │ NULL                        │ 08                   │ 01                               │ 30160011 │
# │ BELO HORIZONTE │ 05161932000563 │ 2314569 │ 05161932    │ RED SAFETY SEGURANCA CONTRA INCENDIO LTDA                │              2062 │ 49                       │ 150000,00      │ 01            │ 2024-02-01    │ 2024-02-01  │ SAVASSI       │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 3983482 │             2 │ NULL                        │ 02                   │ 00                               │ 30130138 │
# │ BELO HORIZONTE │ 26665833000165 │ 1349787 │ 26665833    │ TECNOLOGIA EDUCACIONAL SOLUCOES E CONSULTORIA LTDA       │              2062 │ 49                       │ 364359,00      │ 01            │ 2016-12-06    │ 2016-12-06  │ SILVEIRA      │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 3880317 │             1 │ TED CONSULTING              │ 02                   │ 00                               │ 31140430 │
# │ BELO HORIZONTE │ 10447999000175 │ 2710173 │ 10447999    │ BH TRADE IMPORTACAO E EXPORTACAO & COMERCIO LTDA         │              2062 │ 49                       │ 250000,00      │ 01            │ 2008-10-30    │ 2008-10-30  │ UNIAO         │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 4863480 │             2 │ GREEN PET                   │ 02                   │ 00                               │ 31160370 │
# │ BELO HORIZONTE │ 53742223000190 │ 2822601 │ 53742223    │ FOCUS LTDA                                               │              2062 │ 49                       │ 1000,00        │ 01            │ 2024-01-31    │ 2024-01-31  │ TREVO         │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 6730340 │             1 │ FOCUS SOLUCOES INTELIGENTES │ 02                   │ 00                               │ 31545170 │
# │ BELO HORIZONTE │ 11995066000266 │ 3116238 │ 11995066    │ LUCIANO COSTA FERNANDES                                  │              2135 │ 50                       │ 5000,00        │ 01            │ 2020-06-15    │ 2014-04-03  │ SAVASSI       │ MICRO EMPRESA │ Empresario (Individual)       │ NULA     │  273880 │             2 │ LF SISTEMAS                 │ 08                   │ 01                               │ 30130012 │
# │ BELO HORIZONTE │ 90722323002206 │  351079 │ 90722323    │ DATA CONTROL COMERCIO E SERVICOS EM INFORMATICA LTDA     │              2062 │ 49                       │ 0,00           │ 01            │ 2023-11-13    │ 1993-09-23  │ CENTRO        │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 6068895 │             2 │ NULL                        │ 04                   │ 63                               │ 30180000 │
# │ BELO HORIZONTE │ 31605391000100 │ 2966370 │ 31605391    │ ALUAR ELETRO LTDA                                        │              2062 │ 49                       │ 300000,00      │ 01            │ 2018-09-25    │ 2018-09-25  │ BARREIRO      │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 5573841 │             1 │ ALUAR                       │ 02                   │ 00                               │ 30640520 │
# │ BELO HORIZONTE │ 02080705000353 │ 4532334 │ 02080705    │ ELETRO MULTILOG - DISTRIBUIDOR INDUSTRIA E SERVICOS LTDA │              2062 │ 49                       │ 0,00           │ 01            │ 2018-10-24    │ 2008-06-03  │ SAO FRANCISCO │ MICRO EMPRESA │ Sociedade Empresaria Limitada │ NULA     │ 3342991 │             2 │ NULL                        │ 04                   │ 63                               │ 31255180 │
# ├────────────────┴────────────────┴─────────┴─────────────┴──────────────────────────────────────────────────────────┴───────────────────┴──────────────────────────┴────────────────┴───────────────┴───────────────┴─────────────┴───────────────┴───────────────┴───────────────────────────────┴──────────┴─────────┴───────────────┴─────────────────────────────┴──────────────────────┴──────────────────────────────────┴──────────┤
# │ 10 rows                                                                                                                                                                                                                                                                                                                                                                                                                       21 columns │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df1 = conn.sql("SELECT * FROM bronze_cnae ").set_alias("r1")
df2 = conn.sql("SELECT * FROM silver_cnae_empresa ").set_alias("r2")
df1.join(df2, "r1.codigo = r2.cnae").show()
# Out:
# ┌─────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────┬─────────┬───────────┐
# │ codigo  │                                              descricao                                              │ cnpj_basico │  cnae   │   tipo    │
# │ varchar │                                               varchar                                               │   varchar   │ varchar │  varchar  │
# ├─────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────┼─────────┼───────────┤
# │ 8112500 │ Condomínios prediais                                                                                │ 01330283    │ 8112500 │ principal │
# │ 6422100 │ Bancos múltiplos, com carteira comercial                                                            │ 60746948    │ 6422100 │ principal │
# │ 2599399 │ Fabricação de outros produtos de metal não especificados anteriormente                              │ 04717359    │ 2599399 │ principal │
# │ 8299799 │ Outras atividades de serviços prestados principalmente às empresas não especificadas anteriormente  │ 02953452    │ 8299799 │ principal │
# │ 7319099 │ Outras atividades de publicidade não especificadas anteriormente                                    │ 04721851    │ 7319099 │ principal │
# │ 8299799 │ Outras atividades de serviços prestados principalmente às empresas não especificadas anteriormente  │ 02955072    │ 8299799 │ principal │
# │ 4781400 │ Comércio varejista de artigos do vestuário e acessórios                                             │ 04723272    │ 4781400 │ principal │
# │ 9430800 │ Atividades de associações de defesa de direitos sociais                                             │ 02955181    │ 9430800 │ principal │
# │ 7732201 │ Aluguel de máquinas e equipamentos para construção sem operador, exceto andaimes                    │ 06890089    │ 7732201 │ principal │
# │ 8610101 │ Atividades de atendimento hospitalar, exceto pronto-socorro e unidades para atendimento a urgências │ 60922168    │ 8610101 │ principal │
# │    ·    │                  ·                                                                                  │    ·        │    ·    │     ·     │
# │    ·    │                  ·                                                                                  │    ·        │    ·    │     ·     │
# │    ·    │                  ·                                                                                  │    ·        │    ·    │     ·     │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 39244502    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 39244894    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 39255139    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 39301640    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 39391817    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 07815176    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 08120361    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 06501122    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 06524293    │ 9492800 │ principal │
# │ 9492800 │ Atividades de organizações políticas                                                                │ 06529430    │ 9492800 │ principal │
# ├─────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────┴─────────┴───────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                           5 columns │
# └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
df = conn.sql("SELECT * FROM bronze_cnae ")
df.order("descricao").limit(4).show()
# Out:
# ┌─────────┬──────────────────────────────────────────────┐
# │ codigo  │                  descricao                   │
# │ varchar │                   varchar                    │
# ├─────────┼──────────────────────────────────────────────┤
# │ 1012101 │ Abate de aves                                │
# │ 1012102 │ Abate de pequenos animais                    │
# │ 1531902 │ Acabamento de calçados de couro sob contrato │
# │ 5231101 │ Administração da infra-estrutura portuária   │
# └─────────┴──────────────────────────────────────────────┘

# %%
df = conn.sql("FROM bronze_cnae ")
df.order("descricao DESC").limit(3).show()
# Out:
# ┌─────────┬──────────────────────────────────────────────────────┐
# │ codigo  │                      descricao                       │
# │ varchar │                       varchar                        │
# ├─────────┼──────────────────────────────────────────────────────┤
# │ 7410299 │ atividades de design não especificadas anteriormente │
# │ 6201502 │ Web design                                           │
# │ 3839401 │ Usinas de compostagem                                │
# └─────────┴──────────────────────────────────────────────────────┘

# %%
df1 = conn.sql("SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_0 WHERE uf = 'MG'")
df2 = conn.sql("SELECT * EXCLUDE (cidade_exterior,codigo_pais) FROM bronze_estabelecimento_1 WHERE uf = 'MG'")
df1.union(df2).show()
# Out:
# ┌─────────────┬────────────┬─────────┬───────────────┬──────────────────────────────────┬──────────────────────┬─────────────────────────┬──────────────────────────────────┬───────────────────────┬────────────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┬─────────────────┬─────────────────────────────┬─────────┬─────────────┬────────────────────────┬──────────┬─────────┬───────────┬─────────┬───────────┬─────────┬───────────┬─────────┬───────────┬─────────────────────────────────────────┬───────────────────┬────────────────────────┐
# │ cnpj_basico │ cnpj_ordem │ cnpj_dv │ identificador │          nome_fantasia           │ situacacao_cadastral │ data_situacao_cadastral │ codigo_motivo_situacao_cadastral │ data_inicio_atividade │ cnae_principal │                                                                                                                                             cnae_secundario                                                                                                                                             │ tipo_logradouro │         logradouro          │ numero  │ complemento │         bairro         │   cep    │   uf    │ municipio │  ddd1   │ telefone1 │  ddd2   │ telefone2 │  ddd3   │ telefone3 │                  email                  │ situacao_especial │ data_situacao_especial │
# │   varchar   │  varchar   │ varchar │     int64     │             varchar              │       varchar        │          int64          │             varchar              │         int64         │    varchar     │                                                                                                                                                 varchar                                                                                                                                                 │     varchar     │           varchar           │ varchar │   varchar   │        varchar         │ varchar  │ varchar │  varchar  │ varchar │  varchar  │ varchar │  varchar  │ varchar │  varchar  │                 varchar                 │      varchar      │         int64          │
# ├─────────────┼────────────┼─────────┼───────────────┼──────────────────────────────────┼──────────────────────┼─────────────────────────┼──────────────────────────────────┼───────────────────────┼────────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────────────────┼─────────────────────────────┼─────────┼─────────────┼────────────────────────┼──────────┼─────────┼───────────┼─────────┼───────────┼─────────┼───────────┼─────────┼───────────┼─────────────────────────────────────────┼───────────────────┼────────────────────────┤
# │ 39721458    │ 0001       │ 75      │             1 │ NULL                             │ 02                   │                20201109 │ 00                               │              20201109 │ 7112000        │ 4120400,4399103                                                                                                                                                                                                                                                                                         │ AVENIDA         │ IMBIARA                     │ 1660    │       A     │ CENTRO                 │ 38183244 │ MG      │ 4079      │ 34      │ 36620559  │ 34      │ 88543144  │ NULL    │ NULL      │ CONTATO@DRDPROJETOSEOBRAS.COM.BR        │ NULL              │                   NULL │
# │ 42567873    │ 0001       │ 20      │             1 │ PIILLAR MATERIAIS DE CONSTRUCAO  │ 02                   │                20210702 │ 00                               │              20210702 │ 4744099        │ NULL                                                                                                                                                                                                                                                                                                    │ RUA             │ ACACIO ALVES ALVIM          │ 2115    │ NULL        │ MARILANDIA             │ 36039395 │ MG      │ 4733      │ 32      │ 32331984  │ NULL    │ NULL      │ NULL    │ NULL      │ JANETELEMPRESA@GMAIL.COM                │ NULL              │                   NULL │
# │ 30745908    │ 0001       │ 95      │             1 │ HIPPER LAVA JATO                 │ 08                   │                20221205 │ 01                               │              20180620 │ 4520005        │ 4930201,5320201                                                                                                                                                                                                                                                                                         │ RUA             │ GODOFREDO MOREIRA LEITE     │ 370     │ FUNDOS      │ SANTA CRUZ             │ 37170000 │ MG      │ 4141      │ 35      │ 97665989  │ NULL    │ NULL      │ NULL    │ NULL      │ OCTAVIO@LIDERCONSULTORIACONTABIL.COM.BR │ NULL              │                   NULL │
# │ 37349550    │ 0001       │ 20      │             1 │ SA CLOTHING                      │ 02                   │                20200608 │ 00                               │              20200608 │ 4781400        │ 4763602,4782201                                                                                                                                                                                                                                                                                         │ PRACA           │ LUZ E CARIDADE              │ 16      │ NULL        │ CENTRO                 │ 38400193 │ MG      │ 5403      │ 34      │ 32359011  │ NULL    │ NULL      │ NULL    │ NULL      │ VIRTUAL@VIRTUALSERVICOS.COM.BR          │ NULL              │                   NULL │
# │ 40141968    │ 0001       │ 52      │             1 │ LEMAR COMERCIO E SERVICOS GERAIS │ 02                   │                20201217 │ 00                               │              20201217 │ 4399103        │ 0142300,0161003,0161099,4120400,4213800,4299599,4311802,4313400,4319300,4330499,4391600,4399104,4399199,4642701,4643501,4763602,4781400,7739099,8129000,8130300                                                                                                                                         │ RUA             │ GUTEMBERG                   │ 70      │ NULL        │ MOCAMBEIRO             │ 35725000 │ MG      │ 4821      │ 31      │ 99187462  │ NULL    │ NULL      │ NULL    │ NULL      │ CARLOSHENRIQUEALVES9511@GMAIL.COM       │ NULL              │                   NULL │
# │ 36281968    │ 0001       │ 80      │             1 │ NULL                             │ 02                   │                20200206 │ 00                               │              20200206 │ 3314799        │ 3314701,3314702,3314703,3314704,3314705,3314706,3314707,3314708,3314709,3314710,3314711,3314712,3314713,3314714,3314715,3314716,3314717,3314718,3314719,3314720,3314721,3314722,4520001,4520003,4520004,4520005,4520006,4520007,4530701,4530702,4530703,4530704,4530705,4530706,4543900,4662100,4663000 │ FAZENDA         │ VARZEA COMPRIDA             │ SN      │ NULL        │ ZONA RURAL             │ 39520000 │ MG      │ 5043      │ 38      │ 91245844  │ NULL    │ NULL      │ NULL    │ NULL      │ NULL                                    │ NULL              │                   NULL │
# │ 03067441    │ 0004       │ 41      │             2 │ FARMACIAS ALIANCA DRUGSTORE      │ 08                   │                20221128 │ 01                               │              20210804 │ 4771701        │ 4729602,4772500                                                                                                                                                                                                                                                                                         │ RUA             │ ANTONIO WELLERSON           │ 334     │ NULL        │ SANTO ANTONIO          │ 36900133 │ MG      │ 4787      │ 33      │ 33315228  │ NULL    │ NULL      │ NULL    │ NULL      │ TANCREDOPOCRANE@HOTMAIL.COM             │ NULL              │                   NULL │
# │ 28422595    │ 0001       │ 92      │             1 │ NULL                             │ 02                   │                20170815 │ 00                               │              20170815 │ 5229099        │ 4923001                                                                                                                                                                                                                                                                                                 │ AVENIDA         │ ANIBAL DE MACEDO            │ 825     │ APT 304     │ ARCADIA                │ 32041370 │ MG      │ 4371      │ 31      │ 33960245  │ NULL    │ NULL      │ NULL    │ NULL      │ CLAUDIOOLIVEIRALUZ@GMAIL.COM            │ NULL              │                   NULL │
# │ 32096932    │ 0001       │ 76      │             1 │ NULL                             │ 08                   │                20221129 │ 01                               │              20181126 │ 5611203        │ 4721104,4723700                                                                                                                                                                                                                                                                                         │ RUA             │ RIBEIRO JUNQUEIRA           │ 128     │ NULL        │ CENTRO                 │ 36700000 │ MG      │ 4767      │ 32      │ 34410000  │ NULL    │ NULL      │ NULL    │ NULL      │ NULL                                    │ NULL              │                   NULL │
# │ 35264983    │ 0001       │ 58      │             1 │ MAC MASS                         │ 08                   │                20221230 │ 01                               │              20191022 │ 5620104        │ 4723700                                                                                                                                                                                                                                                                                                 │ AVENIDA         │ BUENO BRANDAO               │ 304     │ NULL        │ CENTRO                 │ 36570047 │ MG      │ 5427      │ 31      │ 38911589  │ NULL    │ NULL      │ NULL    │ NULL      │ SAC@CONTABILIDADEFARIA.COM              │ NULL              │                   NULL │
# │    ·        │  ·         │ ·       │             · │    ·                             │ ·                    │                    ·    │ ·                                │                  ·    │    ·           │    ·                                                                                                                                                                                                                                                                                                    │  ·              │       ·                     │  ·      │  ·          │   ·                    │    ·     │ ·       │  ·        │ ·       │    ·      │  ·      │  ·        │  ·      │  ·        │            ·                            │  ·                │                     ·  │
# │    ·        │  ·         │ ·       │             · │    ·                             │ ·                    │                    ·    │ ·                                │                  ·    │    ·           │    ·                                                                                                                                                                                                                                                                                                    │  ·              │       ·                     │  ·      │  ·          │   ·                    │    ·     │ ·       │  ·        │ ·       │    ·      │  ·      │  ·        │  ·      │  ·        │            ·                            │  ·                │                     ·  │
# │    ·        │  ·         │ ·       │             · │    ·                             │ ·                    │                    ·    │ ·                                │                  ·    │    ·           │    ·                                                                                                                                                                                                                                                                                                    │  ·              │       ·                     │  ·      │  ·          │   ·                    │    ·     │ ·       │  ·        │ ·       │    ·      │  ·      │  ·        │  ·      │  ·        │            ·                            │  ·                │                     ·  │
# │ 44653146    │ 0001       │ 01      │             1 │ SAUDE ANIMAL                     │ 02                   │                20211221 │ 00                               │              20211221 │ 4771704        │ 4623106,4683400,4744001,4781400,4782201,4789004,4789099                                                                                                                                                                                                                                                 │ RUA             │ SEVERIANO COUTINHO          │ 240     │ NULL        │ CENTRO                 │ 39900000 │ MG      │ 4033      │ 33      │ 88814636  │ NULL    │ NULL      │ NULL    │ NULL      │ SAUDEANIMAL240@GMAIL.COM                │ NULL              │                   NULL │
# │ 44653377    │ 0001       │ 15      │             1 │ NULL                             │ 02                   │                20211221 │ 00                               │              20211221 │ 9602501        │ 4772500,9602502                                                                                                                                                                                                                                                                                         │ AVENIDA         │ DOUTOR ROMUALDO SILVA NEIVA │ 101     │ SALA        │ PARACATUZINHO          │ 38603336 │ MG      │ 4939      │ 38      │ 99035436  │ NULL    │ NULL      │ NULL    │ NULL      │ CONTABILIDADEJOMAR1@GMAIL.COM           │ NULL              │                   NULL │
# │ 44653412    │ 0001       │ 04      │             1 │ SUCATAS ITAMONTE                 │ 08                   │                20230227 │ 01                               │              20211221 │ 4785799        │ 3831901,3831999,3832700,3839499,4686901,4687701,4687703,4744001                                                                                                                                                                                                                                         │ RUA             │ JOAO RIBEIRO DE CARVALHO    │ 245     │ GALPAO.     │ RENNE CHARLIER         │ 37464000 │ MG      │ 4661      │ 35      │ 30258907  │ NULL    │ NULL      │ NULL    │ NULL      │ ADM.FINANCEIRO.RECICLAGEM@GMAIL.COM     │ NULL              │                   NULL │
# │ 44653457    │ 0001       │ 70      │             1 │ NULL                             │ 08                   │                20240108 │ 01                               │              20211221 │ 3101200        │ NULL                                                                                                                                                                                                                                                                                                    │ AVENIDA         │ PEROBAS                     │ 589     │ NULL        │ DISTRITO INDUSTRIAL II │ 35557000 │ MG      │ 4283      │ 37      │ 32442591  │ NULL    │ NULL      │ NULL    │ NULL      │ CAVELAR-FISCAL@HOTMAIL.COM              │ NULL              │                   NULL │
# │ 44653481    │ 0001       │ 00      │             1 │ NULL                             │ 02                   │                20211221 │ 00                               │              20211221 │ 9499500        │ NULL                                                                                                                                                                                                                                                                                                    │ COLONIA         │ VAZ DE MELO                 │ S/N     │ NULL        │ ZONA RURAL             │ 36578899 │ MG      │ 5427      │ 31      │ 88476862  │ NULL    │ NULL      │ NULL    │ NULL      │ MARTINSDIAS1988@GMAIL.COM               │ NULL              │                   NULL │
# │ 44653537    │ 0001       │ 26      │             1 │ NULL                             │ 08                   │                20230526 │ 01                               │              20211221 │ 3299099        │ 4789003                                                                                                                                                                                                                                                                                                 │ RUA             │ MARIA JOSE CORREA BARBOSA   │ 175     │ NULL        │ CRISTO REI             │ 36414434 │ MG      │ 4359      │ 31      │ 87893359  │ NULL    │ NULL      │ NULL    │ NULL      │ FLAVIARIBEIRO31@HOTMAIL.COM             │ NULL              │                   NULL │
# │ 44653692    │ 0001       │ 42      │             1 │ NULL                             │ 02                   │                20211221 │ 00                               │              20211221 │ 1821100        │ 8219999                                                                                                                                                                                                                                                                                                 │ AVENIDA         │ SAO JUDAS                   │ 1048    │ CASA        │ SAO JUDAS TADEU        │ 39402558 │ MG      │ 4865      │ 38      │ 92316385  │ NULL    │ NULL      │ NULL    │ NULL      │ CAUAMARTINSN@GMAIL.COM                  │ NULL              │                   NULL │
# │ 44653714    │ 0001       │ 74      │             1 │ NULL                             │ 02                   │                20211221 │ 00                               │              20211221 │ 4772500        │ NULL                                                                                                                                                                                                                                                                                                    │ RUA             │ PETROPOLIS                  │ 03      │ LOJA        │ VILA BISPO DE MAURA    │ 33938439 │ MG      │ 5091      │ 31      │ 84435712  │ NULL    │ NULL      │ NULL    │ NULL      │ DEISIANESSILVA20@GMAIL.COM              │ NULL              │                   NULL │
# │ 44653790    │ 0001       │ 80      │             1 │ JR PRESTACAO DE SERVICO          │ 08                   │                20220615 │ 01                               │              20211221 │ 4399103        │ 3101200,4321500,4322301,2599301,4330402,4330404,1622699                                                                                                                                                                                                                                                 │ RUA             │ CACARATIBA                  │ 67      │ CASA        │ ACAUA DE MINAS         │ 39655000 │ MG      │ 0642      │ 31      │ 98265545  │ NULL    │ NULL      │ NULL    │ NULL      │ ALOESRODRIGUES@GMAIL.COM                │ NULL              │                   NULL │
# │ 44653963    │ 0001       │ 60      │             1 │ NULL                             │ 02                   │                20211221 │ 00                               │              20211221 │ 7319002        │ NULL                                                                                                                                                                                                                                                                                                    │ RUA             │ EMILIO RIBAS                │ 285     │ NULL        │ VILA TONINHO ZEITUNE   │ 37800000 │ MG      │ 4573      │ 35      │ 35510912  │ NULL    │ NULL      │ NULL    │ NULL      │ RS.CONTABILIDADE@YAHOO.COM.BR           │ NULL              │                   NULL │
# ├─────────────┴────────────┴─────────┴───────────────┴──────────────────────────────────┴──────────────────────┴─────────────────────────┴──────────────────────────────────┴───────────────────────┴────────────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┴─────────────────┴─────────────────────────────┴─────────┴─────────────┴────────────────────────┴──────────┴─────────┴───────────┴─────────┴───────────┴─────────┴───────────┴─────────┴───────────┴─────────────────────────────────────────┴───────────────────┴────────────────────────┤
# │ ? rows (>9999 rows, 20 shown)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                28 columns │
# └─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### CSV to Parquet

# %%
csv_file = 'C:/ProfDaniloSantos/cnpj/dados/gold/empresa.csv'
parquet_file = 'C:/ProfDaniloSantos/cnpj/dados/bronze/a_empresa.parquet'

# Gravação no formato Parquet
query = f"COPY '{csv_file}' TO '{parquet_file}' (FORMAT PARQUET)"
comem.execute(query)

# %%
csv_file = 'C:/ProfDaniloSantos/cnpj/raw/utf/estabelecimento_5.csv'
parquet_file = 'C:/ProfDaniloSantos/cnpj/dados/bronze/a_teste.parquet'

# Gravação no formato Parquet
query = f"COPY '{csv_file}' TO '{parquet_file}' (FORMAT PARQUET)"
comem.execute(query)
# Out:
# ---------------------------------------------------------------------------
# ConversionException                       Traceback (most recent call last)
# Cell In[61], line 6
#       4 # Gravação no formato Parquet
#       5 query = f"COPY '{csv_file}' TO '{parquet_file}' (FORMAT PARQUET)"
# ----> 6 comem.execute(query)
#
# ConversionException: Conversion Error: CSV Error on Line: 3616102
# Original Line: "30453894";"0001";"36";"1";"JS SERVICOS";"02";"20180515";"00";"";"";"20180515";"8211300";"";"RUA";"JUBIABA";"65";"";"VILA MADALENA";"05444030";"SP";"7107";"11";"88047700";"null";"";"";"";"JORGE.STEGMANN@GMAIL.COM";"";""
# Error when converting column "ddd2". Could not convert string "null" to 'BIGINT'
#
# Column ddd2 is being converted as type BIGINT
# This type was auto-detected from the CSV file.
# Possible solutions:
# * Override the type for this column manually by setting the type explicitly, e.g. types={'ddd2': 'VARCHAR'}
# * Set the sample size to a larger value to enable the auto-detection to scan more values, e.g. sample_size=-1
# * Use a COPY statement to automatically derive types from an existing table.
#
#   file = C:/ProfDaniloSantos/cnpj/raw/utf/estabelecimento_5.csv
#   delimiter = ; (Auto-Detected)
#   quote = " (Auto-Detected)
#   escape = " (Auto-Detected)
#   new_line = \r\n (Auto-Detected)
#   header = true (Auto-Detected)
#   skip_rows = 0 (Auto-Detected)
#   comment = \0 (Auto-Detected)
#   date_format =  (Auto-Detected)
#   timestamp_format =  (Auto-Detected)
#   null_padding = 0
#   sample_size = 20480
#   ignore_errors = false
#   all_varchar = 0

# %%
# Leitura do arquivo CSV sem cabeçalhos
query = f"""
    CREATE TABLE dados AS
    SELECT * FROM read_csv_auto(
        '{csv_file}',
        header=True,
        delim=';',
        ignore_errors=True,
        types={{'ddd2': 'VARCHAR'}}
    )
"""
comem.execute(query)
# Gravação no formato Parquet
query = f"COPY 'dados' TO '{parquet_file}' (FORMAT PARQUET)"
comem.execute(query)

# %% [markdown]
# ### Import MySQL

# %%
#Instala plugin mysql
query = "INSTALL mysql;"
conn.execute(query)

#Carrega plugin mysql
query = "LOAD mysql;"
conn.execute(query)

#Conecta no BD Mysql
query = "ATTACH 'host=localhost user=root password=root port=3306 database=maposensine' AS mapos (TYPE MYSQL);"
conn.execute(query)
query = "USE mapos;"
conn.execute(query)

# %%
query = 'SELECT * FROM clientes'
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#    idClientes asaas_id       nomeCliente  sexo  pessoa_fisica  \
# 0           1     None      Block - Ryan  None          False
# 1          33     None          Anna Toy  None           True
# 2          34     None    Smith - Hickle  None          False
# 3          35     None       Irvin Stehr  None           True
# 4          36     None  Darin Luettgen V  None           True
#
#             documento          telefone         celular email senha  \
# 0  00.001.001/0001-01   (89) 93931-7234  (99) 9999-9999
# 1      033.033.033/33   (73) 91856-0160  (99) 9999-9999
# 2  03.034.034/0001-34   (32) 93490-9271  (99) 9999-9999
# 3      035.035.035/35   (44) 90002-9994  (99) 9999-9999
# 4      036.036.036/36   (96) 93600-3469  (99) 9999-9999
#
#   dataCadastro                                    rua numero           bairro  \
# 0   2024-01-01     Travessa Professor Leonelo Fortini   2743           Centro
# 1   2024-01-01               João Sebastião de Amorim   9208           Centro
# 2   2024-01-01  Rua Dulcineia de Souza Castro Esteves  30031  Jardim Eldorado
# 3   2024-01-01                         Delfin Moreira    734           Centro
# 4   2024-01-01      Avenida Antônio Guimarães Peralva  27787     Barbosa Lage
#
#            cidade estado       cep   contato complemento  fornecedor
# 0    Juiz de Fora     MG  36015320     Shari        None        True
# 1    Espera Feliz     MG  36830000     Louis        None       False
# 2  Mar de Espanha     MG  36640000   Lynette        None       False
# 3    Juiz de Fora     MG  36010570      Hugh        None       False
# 4    Juiz de Fora     MG  36085170  Lawrence        None       False

# %%
query = 'CREATE OR REPLACE TABLE mapos_clientes AS FROM clientes'
conn.execute(query)

# %%
query = 'SELECT * FROM mapos_clientes'
result_df = conn.execute(query).fetchdf()
result_df.head()
# Out:
#    idClientes asaas_id       nomeCliente  sexo  pessoa_fisica  \
# 0           1     None      Block - Ryan  None          False
# 1          33     None          Anna Toy  None           True
# 2          34     None    Smith - Hickle  None          False
# 3          35     None       Irvin Stehr  None           True
# 4          36     None  Darin Luettgen V  None           True
#
#             documento          telefone         celular email senha  \
# 0  00.001.001/0001-01   (89) 93931-7234  (99) 9999-9999
# 1      033.033.033/33   (73) 91856-0160  (99) 9999-9999
# 2  03.034.034/0001-34   (32) 93490-9271  (99) 9999-9999
# 3      035.035.035/35   (44) 90002-9994  (99) 9999-9999
# 4      036.036.036/36   (96) 93600-3469  (99) 9999-9999
#
#   dataCadastro                                    rua numero           bairro  \
# 0   2024-01-01     Travessa Professor Leonelo Fortini   2743           Centro
# 1   2024-01-01               João Sebastião de Amorim   9208           Centro
# 2   2024-01-01  Rua Dulcineia de Souza Castro Esteves  30031  Jardim Eldorado
# 3   2024-01-01                         Delfin Moreira    734           Centro
# 4   2024-01-01      Avenida Antônio Guimarães Peralva  27787     Barbosa Lage
#
#            cidade estado       cep   contato complemento  fornecedor
# 0    Juiz de Fora     MG  36015320     Shari        None        True
# 1    Espera Feliz     MG  36830000     Louis        None       False
# 2  Mar de Espanha     MG  36640000   Lynette        None       False
# 3    Juiz de Fora     MG  36010570      Hugh        None       False
# 4    Juiz de Fora     MG  36085170  Lawrence        None       False

# %% [markdown]
# ### Gráficos

# %%
query = '''
    SELECT
        CASE
	    	WHEN porte_empresa = '01' THEN 'MICRO EMPRESA'
    	    WHEN porte_empresa = '03' THEN 'PEQUENO PORTE'
    	    WHEN porte_empresa = '05' THEN 'DEMAIS'
		END as porte,
		count(*) as total
    FROM silver_empresa
	WHERE porte_empresa != '00'
	GROUP BY ALL
    '''

df = conn.execute(query).fetchdf()

# %%
# Criando o gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(df['porte'], df['total'], color='skyblue')
plt.xlabel('Porte')
plt.ylabel('Total')
plt.title('Gráfico de Barras: Porte vs Total')
# Out:
# Text(0.5, 1.0, 'Gráfico de Barras: Porte vs Total')

# %%
# Criando o gráfico de pizza
plt.pie(df['total'], labels=df['porte'], autopct='%1.1f%%', startangle=110)
plt.title('Distribuição do Porte')
plt.axis('equal')
plt.show()

# %%
query = '''
        SELECT
            CAST(
                SUBSTRING(CAST(data_inicio_atividade AS VARCHAR), 1,4) AS INTEGER
            ) AS ano,
            COUNT(*) as total
    FROM silver_estabelecimento
    GROUP BY ALL
    ORDER BY 1
    '''
df = conn.execute(query).fetchdf()
df.head()

# Filtrando
df_filtrado = df[df['ano'] > 2010]

# Criando o gráfico de linha
plt.figure(figsize=(10, 6))
plt.plot(df_filtrado['ano'], df_filtrado['total'], marker='o', linestyle='-', color='b')
plt.xlabel('Ano')
plt.ylabel('Total')
plt.title('Gráfico de Linha: Ano vs Total')
plt.grid(True)

# %% [markdown]
# ### Desconectar DuckDB

# %%
comem = duckdb.connect()
conn.close()
